# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahid-Ali56/Python/blob/main/task18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from string import digits
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
import seaborn as sns

digits=load_digits()
X=digits.data
y=digits.target
X_train,X_test,y_train,y_test=train_test_split(X,y , test_size=0.2, random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf=RandomForestClassifier()
model_rf.fit(X_train,y_train)
pred_rf=model_rf.predict(X_test)
cm_rf = confusion_matrix(y_test, pred_rf)
print("Random Forest Accurcy:",accuracy_score(y_test, pred_rf))
plt.imshow(cm_rf, cmap='Greens')
plt.title('Confusion Matrix - Random Forest')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.colorbar()
plt.show()
# Out:
# Random Forest Accurcy: 0.9833333333333333

# %%
svm_model = SVC(kernel='rbf', random_state=42)
svm_model.fit(X_train, y_train)
pred_svm = svm_model.predict(X_test)
cm_svm= confusion_matrix(y_test,pred_svm)
print("SVM Accuracy:",accuracy_score(y_test,pred_svm))
plt.imshow(cm_svm, cmap='Purples')
plt.title('Confusion Matrix - SVM')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.colorbar()
plt.show()
# Out:
# SVM Accuracy: 0.9916666666666667

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)
print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
cm_knn = confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(8,6))
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Oranges')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - KNN Classifier')
plt.show()
# Out:
# KNN Accuracy: 0.9944444444444445

# %%
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
y_pred_nb = nb_model.predict(X_test)
print("Naive Bayes Accuracy:", accuracy_score(y_test, y_pred_nb))
cm_nb = confusion_matrix(y_test, y_pred_nb)
plt.figure(figsize=(8,6))
plt.imshow(cm_nb, interpolation='nearest', cmap='coolwarm')
plt.title('Confusion Matrix - Naive Bayes Classifier')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Naive Bayes Accuracy: 0.8527777777777777
